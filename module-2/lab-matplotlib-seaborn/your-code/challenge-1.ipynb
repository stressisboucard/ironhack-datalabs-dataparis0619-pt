# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x,y,lw=2,color="green", ls='--')

plt.subplot(1,2,2)
plt.plot(x,z,lw=4, color="orange",ls='-')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig,axes=plt.subplots(1,2)
axes[0].plot(x,y,color="green", lw=3, ls='--')
axes[1].plot(x,z,color="orange", lw=3, ls='-')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig,axes=plt.subplots(1,2,figsize = (8,2))
axes[0].plot(x,y,color="pink", lw=5, ls= '-')
axes[1].plot(x,z,color="blue", lw=3, ls='--')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(10,5))

axes[0].plot(x,y,color="pink", lw=5, ls= '--')
axes[0].set_xlabel('x label')
axes[0].set_ylabel('y label')

axes[1].plot(x,z,color="blue", lw=3, ls='--')
axes[1].set_xlabel('x label')
axes[1].set_ylabel('z label')
# Out:
# Text(0, 0.5, 'z label')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(8,2))
      
axes[0].plot(x, x**2,x, np.exp(x))
axes[0].set_title("Normal")

axes[1].plot(x, x**2,x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic")
# Out:
# Text(0.5, 1.0, 'Logarithmic')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, conduct exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart. Please provide at least one inssight from the plot that you have drawn

# %% [markdown]
# Scatter Plot

# %%
# your code here

# %%
plt.scatter(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %% [markdown]
# Box Whisker Plot

# %%
# your code here

data = pd.read_csv('vehicles.csv')
data.boxplot(column="Combined MPG")

ax = sns.boxplot(x="Fuel Type", y="Highway MPG", data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Regular'),
#  Text(0, 0, 'Premium'),
#  Text(0, 0, 'Diesel'),
#  Text(0, 0, 'Premium and Electricity'),
#  Text(0, 0, 'Premium or E85'),
#  Text(0, 0, 'Premium Gas or Electricity'),
#  Text(0, 0, 'Gasoline or E85'),
#  Text(0, 0, 'Gasoline or natural gas'),
#  Text(0, 0, 'CNG'),
#  Text(0, 0, 'Regular Gas or Electricity'),
#  Text(0, 0, 'Midgrade'),
#  Text(0, 0, 'Regular Gas and Electricity'),
#  Text(0, 0, 'Gasoline or propane')]

# %% [markdown]
# Histogram

# %%
# your code here

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF07D3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF249D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF2782E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF29E860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF2C7DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF2F6390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF31E908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF347EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BDBF347EF0>]],
#       dtype=object)

# %% [markdown]
# Bar Chart

# %%
# your code here

# %%
data['Drivetrain'].value_counts().plot.bar()
